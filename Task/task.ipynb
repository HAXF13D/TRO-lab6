# %% [markdown]
# ##  Построение 3Д модели Ленты Мебиусы

# %% [markdown]
# ### Подключенине необходимых библиотек

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Производим вычисления для построеня графика
#
# Использованная формула:
#
# \begin{equation}
# x = \bigg(1 + \frac{v}{2}\cos\Big(\frac{u}{2}\Big)\bigg)\cos(u) \\
# y = \bigg(1 + \frac{v}{2}\cos\Big(\frac{u}{2}\Big)\bigg)\sin(u) \\
# z = \frac{v}{2}\sin\Big(\frac{u}{2}\Big) \\
# u \in [0; 2\pi], \quad
# v \in [{-1}; 1]
# \end{equation}

# %%
u, v = np.mgrid[0:2*np.pi:50j, -1:1:50j]
x = (1 + (v / 2) * np.cos(u / 2)) * np.cos(u)
y = (1 + (v / 2) * np.cos(u / 2)) * np.sin(u)
z = (v / 2) * np.sin(u / 2)

# %% [markdown]
# ### Построение фигуры:

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap="plasma")
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.text2D(0.25, 0.95, "Mobius Ribbon", transform=ax.transAxes)
plt.show()
